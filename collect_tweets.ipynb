# %%
# For sending GET requests from the API
import requests
# For saving access tokens and for file management when creating and adding to the dataset
import os
# For dealing with json responses we receive from the API
import json
# For displaying the data after
import pandas as pd
# For saving the response data in CSV format
import csv
# For parsing the dates received from twitter in readable formats
import datetime
import dateutil.parser
import unicodedata
#To add wait time between requests
import time

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATA_PATH = '/content/drive/MyDrive/'

# %%
os.environ['TOKEN'] = 'xxxxx'

def auth():
    return os.getenv('TOKEN')

def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers

# %% [markdown]
# Now that we can access the API, we will build the request for the endpoint we are going to use and the parameters we want to pass.

# %%
def create_url(keyword, start_date, end_date, max_results = 500):
    
    search_url = "https://api.twitter.com/2/tweets/search/all" #Change to the endpoint you want to collect data from

    #change params based on the endpoint you are using
    query_params = {'query': keyword,
                    'start_time': start_date,
                    'end_time': end_date,
                    'max_results': max_results,
                    'expansions': 'author_id,in_reply_to_user_id,geo.place_id',
                    'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source',
                    'user.fields': 'id,name,username,public_metrics,verified',
                    'place.fields': 'full_name,id,country,geo,name',
                    'next_token': {}}
    return (search_url, query_params)

# %% [markdown]
# Now that we have the URL, headers, and parameters we want, we will create a function that will put all of this together and connect to the endpoint.

# %%
def connect_to_endpoint(url, headers, params, next_token = None):
    params['next_token'] = next_token   #params object received from create_url function
    response = requests.request("GET", url, headers = headers, params = params)
    print("Endpoint Response Code: " + str(response.status_code))
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
# Create file
csvFile = open(DATA_PATH + "data_may.csv", "a", newline="", encoding='utf-8')
csvWriter = csv.writer(csvFile)

#Create headers for the data you want to save, in this example, we only want save these columns in our dataset
csvWriter.writerow(['author id', 'created_at', 'geo', 'id','lang', 'like_count', 'quote_count', 'reply_count','retweet_count','source','tweet'])
csvFile.close()

# %%
def append_to_csv(json_response, fileName):

    #A counter variable
    counter = 0

    #Open OR create the target CSV file
    csvFile = open(fileName, "a", newline="", encoding='utf-8')
    csvWriter = csv.writer(csvFile)

    #Loop through each tweet
    for tweet in json_response['data']:
        
        # We will create a variable for each since some of the keys might not exist for some tweets
        # So we will account for that

        # 1. Author ID
        author_id = tweet['author_id']

        # 2. Time created
        created_at = dateutil.parser.parse(tweet['created_at'])

        # 3. Geolocation
        if ('geo' in tweet):   
            geo = tweet['geo']['place_id']
        else:
            geo = " "

        # 4. Tweet ID
        tweet_id = tweet['id']

        # 5. Language
        lang = tweet['lang']

        # 6. Tweet metrics
        retweet_count = tweet['public_metrics']['retweet_count']
        reply_count = tweet['public_metrics']['reply_count']
        like_count = tweet['public_metrics']['like_count']
        quote_count = tweet['public_metrics']['quote_count']

        # 7. source
        source = tweet['source']

        # 8. Tweet text
        text = tweet['text']
        
        # Assemble all data in a list
        res = [author_id, created_at, geo, tweet_id, lang, like_count, quote_count, reply_count, retweet_count, source, text]
        
        # Append the result to the CSV file
        csvWriter.writerow(res)
        counter += 1

    # When done, close the CSV file
    csvFile.close()

    # Print the number of tweets for this iteration
    print("# of Tweets added from this response: ", counter)

# %%
#Inputs for tweets
bearer_token = auth()
headers = create_headers(bearer_token)
keyword = "#NFT lang:en"
start_list = ['2021-05-01T00:00:00.000Z']
end_list = ['2021-05-31T23:59:59.999Z']
max_results = 500

#Total number of tweets we collected from the loop
total_tweets = 0

# Create file
#csvFile = open(DATA_PATH + "data_july.csv", "a", newline="", encoding='utf-8')
#csvWriter = csv.writer(csvFile)

#Create headers for the data you want to save, in this example, we only want save these columns in our dataset
#csvWriter.writerow(['author id', 'created_at', 'geo', 'id','lang', 'like_count', 'quote_count', 'reply_count','retweet_count','source','tweet'])
#csvFile.close()

for i in range(0,len(start_list)):

    # Inputs
    count = 0 # Counting tweets per time period
    max_count = 50000000000 # Max tweets per time period
    flag = True
    next_token = None
    
    # Check if flag is true
    while flag:
        # Check if max_count reached
        if count >= max_count:
            break
        print("-------------------")
        print("Token: ", next_token)
        url = create_url(keyword, start_list[i],end_list[i], max_results)
        json_response = connect_to_endpoint(url[0], headers, url[1], next_token)
        result_count = json_response['meta']['result_count']

        if 'next_token' in json_response['meta']:
            # Save the token to use for next call
            next_token = json_response['meta']['next_token']
            print("Next Token: ", next_token)
            if result_count is not None and result_count > 0 and next_token is not None:
                print("Start Date: ", start_list[i])
                append_to_csv(json_response, DATA_PATH + "data_may.csv")
                count += result_count
                total_tweets += result_count
                print("Total # of Tweets added: ", total_tweets)
                print("-------------------")
                time.sleep(5)                
        # If no next token exists
        else:
            if result_count is not None and result_count > 0:
                print("-------------------")
                print("Start Date: ", start_list[i])
                append_to_csv(json_response, DATA_PATH + "data_may.csv")
                count += result_count
                total_tweets += result_count
                print("Total # of Tweets added: ", total_tweets)
                print("-------------------")
                time.sleep(5)
            
            #Since this is the final request, turn flag to false to move to the next time period.
            flag = False
            next_token = None
        time.sleep(5)
print("Total number of results: ", total_tweets)
# Out:
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fostqsbvwqblwmdky06kydpby9cdj1
# Start Date:  2021-04-08T00:00:00.000Z
# # of Tweets added from this response:  446
# Total # of Tweets added:  446
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fostqsbvwqblwmdky06kydpby9cdj1
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fostqsbvwka6q2udpo1rfpou69gm7x
# Start Date:  2021-04-08T00:00:00.000Z
# # of Tweets added from this response:  444
# Total # of Tweets added:  890
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fostqsbvwka6q2udpo1rfpou69gm7x
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fostqs9tvtej1kltudc2vga8uirm9p
# Start Date:  2021-04-08T00:00:00.000Z
# # of Tweets added from this response:  446
# Total # of Tweets added:  1336
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fostqs9tvtej1kltudc2vga8uirm9p
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fostqs9tvounrzoavs7dui7us4o22l
# Start Date:  2021-04-08T00:00:00.000Z
# # of Tweets added from this response:  453
# Total # of Tweets added:  1789
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fostqs9tvounrzoavs7dui7us4o22l
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fostqs9tvkbn9k9aj9uzda580sjgjh
# Start Date:  2021-04-08T00:00:00.000Z
# # of Tweets added from this response:  451
# Total # of Tweets added:  2240
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fostqs9tvkbn9k9aj9uzda580sjgjh
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fostqs9tvhatrwdosrbf4triwnwt4t
# Start Date:  2021-04-08T00:00:00.000Z
# # of Tweets added from this response:  456
# Total # of Tweets added:  2696
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fostqs9tvhatrwdosrbf4triwnwt4t
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fostqs9tl0yq2dszi0dui2xhguf5h9
# Start Date:  2021-04-08T00:00:00.000Z
# # of Tweets added from this response:  437
# Total # of Tweets added:  3133
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fostqs9tl0yq2dszi0dui2xhguf5h9
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fostqs9tkwfafkrri77iav7wegivlp
# Start Date:  2021-04-08T00:00:00.000Z
# # of Tweets added from this response:  450
# Total # of Tweets added:  3583
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fostqs9tkwfafkrri77iav7wegivlp
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fostqs9tkrw9w3oo4ls8dyyz2nytml
# Start Date:  2021-04-08T00:00:00.000Z
# # of Tweets added from this response:  463
# Total # of Tweets added:  4046
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fostqs9tkrw9w3oo4ls8dyyz2nytml
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fostqs9tkotqssx28u7r7101ugm9h9
# Start Date:  2021-04-08T00:00:00.000Z
# # of Tweets added from this response:  475
# Total # of Tweets added:  4521
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fostqs9tkotqssx28u7r7101ugm9h9
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fostqs9ta7281r4ocv7qv1hcoa6d19
# Start Date:  2021-04-08T00:00:00.000Z
# # of Tweets added from this response:  446
# Total # of Tweets added:  4967
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fostqs9ta7281r4ocv7qv1hcoa6d19
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fostqs9ta3zp5zt8wwjkjb9w8c4m0t
# Start Date:  2021-04-08T00:00:00.000Z
# # of Tweets added from this response:  473
# Total # of Tweets added:  5440
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fostqs9ta3zp5zt8wwjkjb9w8c4m0t
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fostqs9ta0y12jbxtudms82ug8alx9
# Start Date:  2021-04-08T00:00:00.000Z
# # of Tweets added from this response: